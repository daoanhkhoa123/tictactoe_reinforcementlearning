# %%
# %%bash
#
# cd /kaggle/working
# rm -rf /kaggle/working/tictactoe_reinforcementlearning
# git clone https://github.com/daoanhkhoa123/tictactoe_reinforcementlearning.git
# ls
# Out:
# tictactoe_reinforcementlearning
# Cloning into 'tictactoe_reinforcementlearning'...

# %%
# %cd /kaggle/working/tictactoe_reinforcementlearning
# %ls
# Out:
# /kaggle/working/tictactoe_reinforcementlearning
# runtimes/  src/

# %% [markdown]
# # Run

# %%
from src.common import RandomController, HumanController, CMDInterface, EmptyInterface, build_2clients

client1, client2 = build_2clients("player", "bot", HumanController(), RandomController(), CMDInterface(), EmptyInterface())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_190/1254550799.py in <cell line: 0>()
# ----> 1 from src.common import RandomController, HumanController, CMDInterface, EmptyInterface, build_2clients
#       2
#       3 client1, client2 = build_2clients("player", "bot", HumanController(), RandomController(), CMDInterface(), EmptyInterface())
#
# /kaggle/working/tictactoe_reinforcementlearning/src/common.py in <module>
#       5 from numpy.typing import NDArray
#       6
# ----> 7 from src.game.client import Client
#       8 from src.game.controller import BaseController
#       9 from src.game.interface import BaseInterface
#
# /kaggle/working/tictactoe_reinforcementlearning/src/game/client.py in <module>
#       2
#       3 from src.game.controller import BaseController
# ----> 4 from src.game.interface import BaseInterface
#       5 from src.game.table import MarkType, Table
#       6
#
# /kaggle/working/tictactoe_reinforcementlearning/src/game/interface.py in <module>
#       1 from numpy.typing import NDArray
# ----> 2 from game.client import Client
#       3
#       4
#       5 class BaseInterface:
#
# ModuleNotFoundError: No module named 'game'
