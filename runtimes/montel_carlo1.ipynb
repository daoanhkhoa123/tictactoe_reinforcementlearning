# %%
# %%bash
#
# cd /kaggle/working
# rm -rf /kaggle/working/tictactoe_reinforcementlearning
# git clone https://github.com/daoanhkhoa123/tictactoe_reinforcementlearning.git
# ls
# Out:
# tictactoe_reinforcementlearning
# Cloning into 'tictactoe_reinforcementlearning'...

# %%
# %cd /kaggle/working/tictactoe_reinforcementlearning
# %ls
# Out:
# /kaggle/working/tictactoe_reinforcementlearning
# push.cmd  README.md  runtimes/  src/

# %% [markdown]
# # Run

# %%
from src.common import RandomController, HumanController, CMDInterface, EmptyInterface, build_2clients, ClientArgs
from src.game.interface import BaseInterface
from src.game.controller import BaseController
from src.game.game import Game

from src.rl_learning.montel_carlo.montel_carlo import MontelCarloClient, MontelCarloController, MontelHyperParams, build_montelclient
from src.rl_learning.montel_carlo.environment import Environment

client1, client2 = build_2clients(
    blu=ClientArgs(
        name="montel-carlo",
        controller=BaseController(),
        interface=BaseInterface(),
    ),
    red=ClientArgs(
        name="random bot",
        controller=RandomController(0),
        interface=BaseInterface(),
    ),
)

params = MontelHyperParams(
    lr=0.05,
    decay_gamma=0.95,
    exp_rate=0.2,
)

client1 =  build_montelclient(client1, params)
client2 = build_montelclient(client2, params)

# %%
print(client1.name, client1.mark_type)
print(client2.name, client2.mark_type)
# Out:
# montel-carlo -1
# random bot 1

# %%
from tqdm import tqdm
game = Game(client1, client2) # type: ignore

count = {}
for _ in tqdm(range(16)):
    game.reset_table()
    winner = game.hajime()
    game.owari(winner)

    count[winner] = count.get(winner, 0) + 1
# Out:
#   6%|▋         | 1/16 [00:00<00:01,  8.60it/s]
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#  31%|███▏      | 5/16 [00:00<00:01,  8.43it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
#  44%|████▍     | 7/16 [00:00<00:01,  8.74it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
#  75%|███████▌  | 12/16 [00:01<00:00,  8.08it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
#  94%|█████████▍| 15/16 [00:01<00:00,  8.14it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
# 100%|██████████| 16/16 [00:01<00:00,  8.56it/s]
# Player montel-carlo won the game!

# %%
count
# Out:
# {<MarkType.BLU: -1>: 11, <MarkType.RED: 1>: 5}

# %%
from tqdm import tqdm
env = Environment(client1, client2, train_both=False) # type: ignore

count = {}
for _ in tqdm(range(1024)):
    env.reset_table()
    winner = env.hajime()
    env.owari(winner)

    count[winner] = count.get(winner, 0) + 1
# Out:
#   0%|          | 3/1024 [00:00<01:13, 13.84it/s]
# Player random bot won the game!
# Player random bot won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
#   1%|          | 9/1024 [00:00<01:19, 12.81it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
# Player random bot won the game!
#   1%|          | 11/1024 [00:00<01:34, 10.73it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
#   1%|▏         | 13/1024 [00:01<01:37, 10.36it/s]
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
#   2%|▏         | 17/1024 [00:01<02:13,  7.56it/s]
# Player random bot won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
#   2%|▏         | 19/1024 [00:02<02:14,  7.50it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   2%|▏         | 23/1024 [00:02<01:49,  9.15it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player random bot won the game!
#   3%|▎         | 26/1024 [00:02<01:48,  9.18it/s]
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   3%|▎         | 30/1024 [00:03<01:51,  8.94it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player random bot won the game!
# Player random bot won the game!
#   3%|▎         | 34/1024 [00:03<02:19,  7.10it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   4%|▍         | 39/1024 [00:04<01:46,  9.22it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   4%|▍         | 41/1024 [00:04<01:37, 10.09it/s]
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   4%|▍         | 46/1024 [00:05<01:40,  9.71it/s]
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
#   5%|▍         | 50/1024 [00:05<01:33, 10.47it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   5%|▌         | 52/1024 [00:05<01:35, 10.16it/s]
# Player random bot won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
# Player montel-carlo won the game!
#   6%|▌         | 58/1024 [00:06<01:43,  9.37it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
# Player random bot won the game!
#   6%|▌         | 61/1024 [00:06<01:40,  9.61it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
#   6%|▌         | 63/1024 [00:06<01:41,  9.50it/s]
# Player random bot won the game!
# Player montel-carlo won the game!
#   6%|▋         | 66/1024 [00:07<01:49,  8.79it/s]
# Player montel-carlo won the game!
# Player random bot won the game!
# Player montel-carlo won the game!
/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_685/2772797173.py in <cell line: 0>()
#       5 for _ in tqdm(range(1024)):
#       6     env.reset_table()
# ----> 7     winner = env.hajime()
#       8     env.owari(winner)
#       9
#
# /kaggle/working/tictactoe_reinforcementlearning/src/game/game.py in hajime(self)
#      29             if self._table.is_full():
#      30                 break
# ---> 31             self.client1.play(self._table)
#      32
#      33             if self._table.is_full():
#
# /kaggle/working/tictactoe_reinforcementlearning/src/rl_learning/montel_carlo/montel_carlo.py in play(self, table)
#     120
#     121     def play(self, table: Table) -> None:
# --> 122         super().play(table)
#     123         hash = self.controller.get_hash(table.get_table(False))
#     124         self.controller.memory.push(hash)
#
# /kaggle/working/tictactoe_reinforcementlearning/src/game/client.py in play(self, table)
#      38         while trial < self._max_trial:
#      39             trial += 1
# ---> 40             y, x =self.controller.decide(state)
#      41             good_move = table.mark(y, x, self.mark_type)
#      42             if good_move:
#
# /kaggle/working/tictactoe_reinforcementlearning/src/game/controller.py in decide(self, input_state)
#      46         """
#      47         model_input = self.pre_processing(input_state)
# ---> 48         model_output = self.model_call(model_input)
#      49         return self.post_processing(model_output)
#      50
#
# /kaggle/working/tictactoe_reinforcementlearning/src/rl_learning/montel_carlo/montel_carlo.py in model_call(self, model_input)
#      79             return self.state_value.get(key, 0.0)
#      80
# ---> 81         return max(positions, key=value_of_sprime)
#      82
#      83     def post_processing(self, model_output: Action) -> Action:
#
# /kaggle/working/tictactoe_reinforcementlearning/src/rl_learning/montel_carlo/montel_carlo.py in value_of_sprime(pos)
#      76             next_state[pos[0], pos[1]] = self.mark_type
#      77
# ---> 78             key = self.get_hash(next_state)
#      79             return self.state_value.get(key, 0.0)
#      80
#
# /kaggle/working/tictactoe_reinforcementlearning/src/rl_learning/montel_carlo/montel_carlo.py in get_hash(state)
#      58     @staticmethod
#      59     def get_hash(state: NDArray) -> str:
# ---> 60         return str(state.flatten())
#      61
#      62     def pre_processing(self, input_state: NDArray) -> Tuple[NDArray, List[Action]]:
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1667         return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
#    1668
# -> 1669     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1670
#    1671
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     760         return "[]"
#     761
# --> 762     return _array2string(a, options, separator, prefix)
#     763
#     764
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in wrapper(self, *args, **kwargs)
#     532             repr_running.add(key)
#     533             try:
# --> 534                 return f(self, *args, **kwargs)
#     535             finally:
#     536                 repr_running.discard(key)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _array2string(a, options, separator, prefix)
#     565     next_line_prefix += " "*len(prefix)
#     566
# --> 567     lst = _formatArray(a, format_function, options['linewidth'],
#     568                        next_line_prefix, separator, options['edgeitems'],
#     569                        summary_insert, options['legacy'])
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     919     try:
#     920         # invoke the recursive part with an initial index and prefix
# --> 921         return recurser(index=(),
#     922                         hanging_indent=next_line_prefix,
#     923                         curr_width=line_width)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     872
#     873             for i in range(trailing_items, 1, -1):
# --> 874                 word = recurser(index + (-i,), next_hanging_indent, next_width)
#     875                 s, line = _extendLine_pretty(
#     876                     s, line, word, elem_width, hanging_indent, legacy)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     823
#     824         if axes_left == 0:
# --> 825             return format_function(a[index])
#     826
#     827         # when recursing, add a space to align with the [ added, and reduce the
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/arrayprint.py in __call__(self, x)
#    1271         self.format = f'{{:{sign}{max_str_len}d}}'
#    1272
# -> 1273     def __call__(self, x):
#    1274         return self.format.format(x)
#    1275
#
# KeyboardInterrupt:

# %%
count
# Out:
# {<MarkType.RED: 1>: 6, <MarkType.BLU: -1>: 10}
