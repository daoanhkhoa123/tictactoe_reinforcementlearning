# %%
# %%bash
#
# cd /kaggle/working
# rm -rf /kaggle/working/tictactoe_reinforcementlearning
# git clone https://github.com/daoanhkhoa123/tictactoe_reinforcementlearning.git
# ls
# Out:
# tictactoe_reinforcementlearning
# Cloning into 'tictactoe_reinforcementlearning'...

# %%
# %cd /kaggle/working/tictactoe_reinforcementlearning
# %ls
# Out:
# /kaggle/working/tictactoe_reinforcementlearning
# push.cmd  README.md  runtimes/  src/

# %% [markdown]
# # Run

# %%
from src.common import RandomController, HumanController, CMDInterface, EmptyInterface, build_2clients, ClientArgs
from src.game.game import Game

from src.rl_learning.montel_carlo.montel_carlo import MontelCarloClient, MontelCarloController, MontelHyperParams, build_montelclient
from src.rl_learning.montel_carlo.environment import Environment

client1, client2 = build_2clients(
    blu=ClientArgs(
        name="random bot",
        controller=RandomController(0),
        interface=EmptyInterface(),
    ),
    red=ClientArgs(
        name="montel-carlo",
        controller=RandomController(),
        interface=EmptyInterface(),
    ),
)

params = MontelHyperParams(
    lr=0.05,
    decay_gamma=0.95,
    exp_rate=0.2,
)

client =  build_montelclient(client1, params)

# %%
client.controller.state_value
# Out:
# {}

# %%
from tqdm import tqdm
env = Environment(client, client2)

for _ in tqdm(range(128)):
    winner = env.hajime()
    env.owari(winner)
# Out:
#   0%|          | 0/128 [00:00<?, ?it/s]
# Bot is thinking...
# Montel chose (np.int64(6), np.int64(6))
# Bot is thinking...
# Bot chose: (np.int64(6), np.int64(4))
# Bot is thinking...
# Montel chose (np.int64(6), np.int64(5))
# Bot is thinking...
# Bot chose: (np.int64(6), np.int64(0))
# Bot is thinking...
# Montel chose (np.int64(6), np.int64(3))
# Bot is thinking...
# Bot chose: (np.int64(0), np.int64(5))
# Bot is thinking...
# Montel chose (np.int64(3), np.int64(6))
# Bot is thinking...
# Bot chose: (np.int64(2), np.int64(4))
# Bot is thinking...
# Montel chose (np.int64(6), np.int64(2))
# Bot is thinking...
# Bot chose: (np.int64(5), np.int64(1))
# Bot is thinking...
# Montel chose (np.int64(6), np.int64(1))
# Bot is thinking...
# Bot chose: (np.int64(3), np.int64(0))
# Bot is thinking...
# Montel chose (np.int64(4), np.int64(2))
# Bot is thinking...
# Bot chose: (np.int64(1), np.int64(0))
# Bot is thinking...
# Montel chose (np.int64(5), np.int64(6))
# Bot is thinking...
# Bot chose: (np.int64(5), np.int64(3))
# Bot is thinking...
# Montel chose (np.int64(5), np.int64(5))
# Bot is thinking...
# Bot chose: (np.int64(4), np.int64(1))
# Bot is thinking...
# Montel chose (np.int64(3), np.int64(5))
# Bot is thinking...
# Bot chose: (np.int64(4), np.int64(3))
# Bot is thinking...
# Montel chose (np.int64(2), np.int64(3))
# Bot is thinking...
# Bot chose: (np.int64(0), np.int64(4))
# Bot is thinking...
# Montel chose (np.int64(5), np.int64(4))
# Bot is thinking...
# Bot chose: (np.int64(4), np.int64(4))
# Bot is thinking...
# Montel chose (np.int64(5), np.int64(2))
# Bot is thinking...
# Bot chose: (np.int64(3), np.int64(1))
# Bot is thinking...
# Montel chose (np.int64(5), np.int64(0))
# Bot is thinking...
# Bot chose: (np.int64(0), np.int64(2))
# Bot is thinking...
# Montel chose (np.int64(4), np.int64(6))
# Bot is thinking...
# 100%|██████████| 128/128 [00:45<00:00,  2.84it/s]
# Bot chose: (np.int64(2), np.int64(2))
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!
# Draw!

# %%
[*client.controller.memory]
# Out:
# []
